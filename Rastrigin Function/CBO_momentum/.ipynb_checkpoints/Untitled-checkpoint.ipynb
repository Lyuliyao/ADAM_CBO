% %%
ADAM_levy(30,500,5,100,10,0.1)
% Out:
% ans =
%
%     'diff: 12.249348,m:0.142088'
%
%
% ans =
%
%     'epoch =500,error= 4.319787'
%
%
% ans =
%
%     'diff: 31.621403,m:0.126691'
%
%
% ans =
%
%     'epoch =1000,error= 3.285520'
%
%
% ans =
%
%     'diff: 36.635823,m:0.131442'
%
%
% ans =
%
%     'epoch =1500,error= 3.165370'
%
%
% ans =
%
%     'diff: 34.659320,m:0.086689'
%
%
% ans =
%
%     'epoch =2000,error= 2.084470'
%
%
% ans =
%
%     'diff: 22.220363,m:0.090323'
%
%
% ans =
%
%     'epoch =2500,error= 1.892137'
%
%
% ans =
%
%     'diff: 11.201916,m:0.040793'
%
%
% ans =
%
%     'epoch =3000,error= 2.006315'
%
%
% ans =
%
%     'diff: 5.126155,m:0.035659'
%
%
% ans =
%
%     'epoch =3500,error= 1.980754'
%
%
% ans =
%
%     'diff: 2.148321,m:0.024900'
%
%
% ans =
%
%     'epoch =4000,error= 1.976902'
%
%
% ans =
%
%     'diff: 0.798754,m:0.007331'
%
%
% ans =
%
%     'epoch =4500,error= 1.994268'
%
%
% ans =
%
%     'diff: 0.368632,m:0.001700'
%
%
% ans =
%
%     'epoch =5000,error= 2.003812'
%
%
% ans =
%
% ...
